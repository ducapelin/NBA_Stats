# %%
import pandas as pd
import os
from pathlib import Path

# %%
base_path = "C:/Users/PERFORMANCE/SVN Investimentos/Performance e Gestão - Documentos/1. Projetos Macro/00.BD/0.Brutas/"
relatorios = ["positivador_v2","positivador"]
escritorios = ["SVN", "BP", "SVN Connect"]

files = []

for relatorio in relatorios:
    for escritorio in escritorios:
        specific_path = f"{base_path}{escritorio}/{relatorio}"
        files.extend(os.listdir(specific_path))
    


print(files)
print(len(files))
# Out:
# ['Relatório Positivador 20230426.xlsx', 'Relatório Positivador 20230428.xlsx', 'Relatório Positivador 20230502.xlsx', 'Relatório Positivador 20230503.xlsx', 'Relatório Positivador 20230504.xlsx', 'Relatório Positivador 20230505.xlsx', 'Relatório Positivador 20230508.xlsx', 'Relatório Positivador 20230509.xlsx', 'Relatório Positivador 20230510.xlsx', 'Relatório Positivador 20230511.xlsx', 'Relatório Positivador 20230512.xlsx', 'Relatório Positivador 20230518.xlsx', 'Relatório Positivador 20230519.xlsx', 'Relatório Positivador 20230524.xlsx', 'Relatório Positivador 20230525.xlsx', 'Relatório Positivador 20230529.xlsx', 'Relatório Positivador 20230531.xlsx', 'Relatório Positivador 20230601.xlsx', 'Relatório Positivador 20230602.xlsx', 'Relatório Positivador 20230606.xlsx', 'Relatório Positivador 20230607.xlsx', 'Relatório Positivador 20230612.xlsx', 'Relatório Positivador 20230614.xlsx', 'Relatório Positivador 20230615.xlsx', 'Relatório Positivador 20230616.xlsx', 'Relatório Positivador
# ...

# %%
escritorios = ["SVN", "BP", "SVN Connect"]
relatorios = ["positivador_v2", "positivador"]

path = "C:/Users/PERFORMANCE/SVN Investimentos/Performance e Gestão - Documentos/1. Projetos Macro/00.BD/0.Brutas/SVN/positivador_v2/Relatório Positivador 20241107.xlsx"

data = pd.read_excel(path)

print(data)
# Out:
#        Assessor  Cliente                                        Profissão  \
# 0         51949  3594112                                           OUTROS
# 1         33101  8002766                                         ADVOGADO
# 2         20655  2280634                                           OUTROS
# 3         73516    41641  CORRETOR DE IMOVEIS, SEGUROS, TITULOS E VALORES
# 4         72854  9181796                                           OUTROS
# ...         ...      ...                                              ...
# 10952     26594  6010367                              DIRETOR DE EMPRESAS
# 10953     71496  6026072            PROFESSOR DE PRIMEIRO E SEGUNDO GRAUS
# 10954     26594  6069148                              DIRETOR DE EMPRESAS
# 10955     70772  6094545          APOSENTADO (EXCETO FUNCIONARIO PUBLICO)
# 10956     41812  3348642                        VETERINARIO E ZOOTECNISTA
#
#       Sexo        Segmento Data de Cadastro Fez Segundo Aporte?  \
# ...
